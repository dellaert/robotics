# %% [markdown]
# # DuckieBot I
# * Robot: DuckieBot
# * Sensor: wheel encoder
# * Think: localize
# * Act: DD
# * Topics needed: DD kinematics, sensor fusion, localization (MCL), factor graphs & KF
# * Factor graph concepts: Kalman filter

# %% [markdown]
# ## [Differential Drive kinematics](Kinematics)

# %% [markdown]
# ## Sensor Fusion

# %% [markdown]
# ## Factor Graphs

# %% [markdown]
# ## Localization

# %% [markdown]
# ## The Kalman Filter

# %% [markdown]
# ## Monte Carlo Localization
